# %% [markdown]
# # MALIS 19.3 WPM_T9.2 Frage 5
# ## Datenanalyse der offenen Daten der Seattle Library
#
#
# Die URL definiert in welcher Größe die Datenmengen abgerufen werden. So kann man die URL auf Zeilen (standartmäßig 1000) oder auf Jahre begrenzen. Für die Fragen wurde ist ein Limit von 3.000.000 Zeilen genommen, damit sind alle Checkouts des Jahres 2018 enthalten.
# Folgende fünf Fragen sollen mittels der Datenanalyse beantwortet werden:

# %% [markdown]
# # Frage 5 "Sieht man von 2005 bis 2018 eine Veränderung der UsageClass? Wie ist das Verhältnis der Ausleihen zwischen digitalen und physischen Medien?"
#
# Hierfür wird zunächst pandas nach Anleitung heruntergeladen. Dann werden die Daten importiert.

# %%
import urllib.request
import pandas as pd
import matplotlib.pyplot as plt

# %%
urlfuenf = "https://data.seattle.gov/resource/tmmm-ytt6.csv?$where=checkoutyear=2005&$limit=3000000"
urlachtzehn = "https://data.seattle.gov/resource/tmmm-ytt6.csv?$where=checkoutyear=2018&$limit=3000000"
fuenf = "Checkoutsfuenf.csv"
achtzehn = "Checkoutsachtzehn.csv"

# %%
# Download der Daten
#urllib.request.urlretrieve(urlfuenf, fuenf)
#urllib.request.urlretrieve(urlachtzehn, achtzehn)

# %%
checkoutfuenf = pd.read_csv(fuenf)
checkoutachtzehn = pd.read_csv(achtzehn)

# %%
checkoutfuenf
# Out:
#         usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0         Physical      Horizon         BOOK          2005              4
# 1         Physical      Horizon         BOOK          2005              4
# 2         Physical      Horizon         BOOK          2005              4
# 3         Physical      Horizon         BOOK          2005              4
# 4         Physical      Horizon         BOOK          2005              4
# ...            ...          ...          ...           ...            ...
# 1331647   Physical      Horizon    SOUNDDISC          2005             12
# 1331648   Physical      Horizon         BOOK          2005             12
# 1331649   Physical      Horizon         BOOK          2005             12
# 1331650   Physical      Horizon         BOOK          2005             12
# 1331651   Physical      Horizon         BOOK          2005             12
#
#          checkouts                                              title  \
# ...

# %%
checkoutachtzehn
# Out:
#         usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0         Physical      Horizon         BOOK          2018             12
# 1         Physical      Horizon         BOOK          2018             12
# 2         Physical      Horizon    VIDEODISC          2018             12
# 3          Digital    OverDrive    AUDIOBOOK          2018             12
# 4         Physical      Horizon         BOOK          2018             12
# ...            ...          ...          ...           ...            ...
# 2665093    Digital       Hoopla        MUSIC          2018              1
# 2665094   Physical      Horizon         BOOK          2018              1
# 2665095   Physical      Horizon         BOOK          2018              1
# 2665096   Physical      Horizon         BOOK          2018              1
# 2665097   Physical      Horizon         BOOK          2018              1
#
#          checkouts                                              title  \
# ...

# %%
checkoutfuenf.columns
# Out:
# Index(['usageclass', 'checkouttype', 'materialtype', 'checkoutyear',
#        'checkoutmonth', 'checkouts', 'title', 'creator', 'subjects',
#        'publisher', 'publicationyear'],
#       dtype='object')

# %%
checkoutachtzehn.columns
# Out:
# Index(['usageclass', 'checkouttype', 'materialtype', 'checkoutyear',
#        'checkoutmonth', 'checkouts', 'title', 'creator', 'subjects',
#        'publisher', 'publicationyear'],
#       dtype='object')

# %%
fuenfp = checkoutfuenf.pivot_table(index = "usageclass", values = "title", aggfunc="count")

# %%
fuenfp
# Out:
#               title
# usageclass
# Digital        3521
# Physical    1328131

# %%
achtp = checkoutachtzehn.pivot_table(index = "usageclass", values = "title", aggfunc="count")

# %%
achtp
# Out:
#               title
# usageclass
# Digital      966418
# Physical    1698680

# %%
achtp.divide()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-49f98524e2a4> in <module>
# ----> 1 achtp.divide()
#
# TypeError: f() missing 1 required positional argument: 'other'
